# %% [markdown]
# ## Fraud Risk Profiling & Anomaly Detection in Bank Accounts ##
# #### Business Question:
# Which account and transaction characteristics signal fraudulent account openings, and how can a fraud team prioritize investigations?
#
# A fraud detection analysis that helps a bank's fraud team understand:
# - **Who** is committing fraud (what do fraudulent applicants look like?)
# - **How** they behave differently from legitimate customers
# - **Where** the bank should focus its investigation efforts
#
# Each record in the dataset represents a single transaction or application event, enriched with customer, behavioral, and identity-related attributes.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/Base.csv")
df.head()
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
# 2           0     0.8               0.996707                          9
# 3           0     0.6               0.475100                         11
# 4           0     0.9               0.842307                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
# 2                            14            40            0.012316
# 3                            14            30            0.006991
# 4                            29            40            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# 0              102.453711           AA          1059  ...                0
# 1               -0.849551           AD          1658  ...                0
# 2               -1.490386           AB          1095  ...                0
# 3               -1.863101           AB          3483  ...                0
# 4               47.152498           AA          2339  ...                0
#
#    proposed_credit_limit  foreign_request    source  \
# 0                 1500.0                0  INTERNET
# 1                 1500.0                0  INTERNET
# 2                  200.0                0  INTERNET
# 3                  200.0                0  INTERNET
# 4                  200.0                0  INTERNET
#
#    session_length_in_minutes device_os  keep_alive_session  \
# 0                  16.224843     linux                   1
# 1                   3.363854     other                   1
# 2                  22.730559   windows                   0
# 3                  15.215816     linux                   1
# 4                   3.743048     other                   0
#
#    device_distinct_emails_8w device_fraud_count  month
# 0                          1                  0      0
# 1                          1                  0      0
# 2                          1                  0      0
# 3                          1                  0      0
# 4                          1                  0      0
#
# [5 rows x 32 columns]

# %% [markdown]
# **Each row = one application / transaction event**
#
# ##### Transaction:
# - fraud_bool - Fraud label (1 if fraud, 0 if legit)
# - credit_risk_score - Internal score of application risk. Ranges between [−170, 389].
# - proposed_credit_limit - Applicant’s proposed credit limit. Ranges between [190, 2100].
# - intended_balcon_amount - Initial transferred amount for application. Ranges between [−16, 113].
# - payment_type - Credit payment plan type. 5 possible (annonymized) values.
# - foreign_request - If origin country of request is different from bank’s country (0 for same country, 1 for different country).
# - bank_branch_count_8w - Number of total applications in the selected bank branch in last 8 weeks. Ranges between [0, 2385].
#
# ##### Customer:
# - income - annual income of the applicant in quantiles. Ranges between [0, 1]
# - customer_age - Applicant’s age in bins per decade (e.g, 20-29 is represented as 20).
# - prev_address_months_count - Number of months in previous registered address of the applicant, i.e. the applicant’s previous residence, if applicable. Ranges between [−1, 383] months (-1 is a missing value).
# - current_address_months_count - Months in currently registered address of the applicant. Ranges between [−1, 428] months (-1 is a missing value).
# - housing_status - Current residential status for applicant. 7 possible (annonymized) values.
# - employment_status - Employment status of the applicant. 7 possible (annonymized) values.
# - has_other_cards - If applicant has other cards from the same banking company (0 for no other cards, 1 for other cards).
#
# ##### Session:
# - device_os - Operative system of device that made request. Possible values are: Windows, Macintosh, Linux, X11, or other.
# - source - Online source of application. Either browser(INTERNET) or mobile app (APP).
# - session_length_in_minutes - Length of user session in banking website in minutes. Ranges between [−1, 86] minutes
# - keep_alive_session - User option on session logout (0 for not kept alive, 1 for kept alive).
# - device_distinct_emails_8w - Number of distinct emails in banking website from the used device in last 8 weeks. Ranges between [-1, 2] (-1 is a missing value).
# - velocity_6h - Velocity of total applications made in last 6 hours i.e., average number of applications per hour in the last 6 hours. Ranges between [−211, 24763].
# - velocity_24h - Velocity of total applications made in last 24 hours i.e., average number of applications per hour in the last 24 hours. Ranges between [1329, 9527].
# - velocity_4w - Velocity of total applications made in last 4 weeks, i.e., average number of applications per hour in the last 4 weeks. Ranges between [2779, 7043].
#
# ##### Identity
# - name_email_similarity - Metric of similarity between email and applicant’s name. Higher values represent higher similarity. Ranges between [0, 1].
# - email_is_free - Domain of application email (0 for paid, 1 for free).
# - phone_home_valid - Validity of provided home phone (0 for invalid, 1 for valid).
# - phone_mobile_valid - Validity of provided mobile phone (0 for invalid, 1 for valid).
# - date_of_birth_distinct_emails_4w - Number of different emails used with the same date of birth (last 4 weeks). Ranges between [0, 39].
#
#
# ##### Other feautures:
# - days_since_request - Number of days passed since application was done. Ranges between [0, 78] days.
# - bank_months_count - How old is previous account (if held) in months. Ranges between [−1, 31] months (-1 is a missing value).
# - zip_count_4w - Number of applications within same zip code in last 4 weeks. Ranges between [1, 5767].
# - month - Month where the application was made. Ranges between [0, 7].
# - device_fraud_count - Number of fraudulent applications with used device. Ranges between [0, 1].

# %%
df.shape
# Out:
# (1000000, 32)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  int64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  int64
#  4   current_address_months_count      1000000 non-null  int64
#  5   customer_age                      1000000 non-null  int64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            1000000 non-null  float64
#  8   payment_type                      1000000 non-null  str
#  9   zip_count_4w                      1000000 non-null  int64
#  10  velocity_6h                       1000000 non-null  float64
#  11  velocity_24h                      1000000 non-null  float64
#  12  velocity_4w                       1000000 non-null  float64
#  13  bank_branch_count_8w              1000000 non-null  int64
#  14  date_of_birth_distinct_emails_4w  1000000 non-null  int64
#  15  employment_status                 1000000 non-null  str
#  16  credit_risk_score                 1000000 non-null  int64
#  17  email_is_free                     1000000 non-null  int64
#  18  housing_status                    1000000 non-null  str
#  19  phone_home_valid                  1000000 non-null  int64
#  20  phone_mobile_valid                1000000 non-null  int64
#  21  bank_months_count                 1000000 non-null  int64
#  22  has_other_cards                   1000000 non-null  int64
#  23  proposed_credit_limit             1000000 non-null  float64
#  24  foreign_request                   1000000 non-null  int64
#  25  source                            1000000 non-null  str
#  26  session_length_in_minutes         1000000 non-null  float64
#  27  device_os                         1000000 non-null  str
#  28  keep_alive_session                1000000 non-null  int64
#  29  device_distinct_emails_8w         1000000 non-null  int64
#  30  device_fraud_count                1000000 non-null  int64
#  31  month                             1000000 non-null  int64
# dtypes: float64(9), int64(18), str(5)
# memory usage: 244.1 MB

# %%
df.nunique()
# Out:
# fraud_bool                               2
# income                                   9
# name_email_similarity               998861
# prev_address_months_count              374
# current_address_months_count           423
# customer_age                             9
# days_since_request                  989330
# intended_balcon_amount              994971
# payment_type                             5
# zip_count_4w                          6306
# velocity_6h                         998687
# velocity_24h                        998940
# velocity_4w                         998318
# bank_branch_count_8w                  2326
# date_of_birth_distinct_emails_4w        40
# employment_status                        7
# credit_risk_score                      551
# email_is_free                            2
# housing_status                           7
# phone_home_valid                         2
# phone_mobile_valid                       2
# bank_months_count                       33
# has_other_cards                          2
# proposed_credit_limit                   12
# foreign_request                          2
# source                                   2
# session_length_in_minutes           994887
# device_os                                5
# keep_alive_session                       2
# device_distinct_emails_8w                4
# device_fraud_count                       1
# month                                    8
# dtype: int64

# %%
df['fraud_bool'].value_counts()
# Out:
# fraud_bool
# 0    988971
# 1     11029
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df["fraud_bool"].value_counts().plot(kind="bar")

plt.title("Fraud vs Non-Fraud Distribution")
plt.xlabel("Fraud (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

# %%
df.describe()
# Out:
#            fraud_bool          income  name_email_similarity  \
# count  1000000.000000  1000000.000000         1000000.000000
# mean         0.011029        0.562696               0.493694
# std          0.104438        0.290343               0.289125
# min          0.000000        0.100000               0.000001
# 25%          0.000000        0.300000               0.225216
# 50%          0.000000        0.600000               0.492153
# 75%          0.000000        0.800000               0.755567
# max          1.000000        0.900000               0.999999
#
#        prev_address_months_count  current_address_months_count  \
# count             1000000.000000                1000000.000000
# mean                   16.718568                     86.587867
# std                    44.046230                     88.406599
# min                    -1.000000                     -1.000000
# 25%                    -1.000000                     19.000000
# 50%                    -1.000000                     52.000000
# 75%                    12.000000                    130.000000
# max                   383.000000                    428.000000
#
#          customer_age  days_since_request  intended_balcon_amount  \
# count  1000000.000000        1.000000e+06          1000000.000000
# mean        33.689080        1.025705e+00                8.661499
# std         12.025799        5.381835e+00               20.236155
# min         10.000000        4.036860e-09              -15.530555
# 25%         20.000000        7.193246e-03               -1.181488
# 50%         30.000000        1.517574e-02               -0.830507
# 75%         40.000000        2.633069e-02                4.984176
# max         90.000000        7.845690e+01              112.956928
#
#          zip_count_4w     velocity_6h  ...  phone_mobile_valid  \
# count  1000000.000000  1000000.000000  ...      1000000.000000
# mean      1572.692049     5665.296605  ...            0.889676
# std       1005.374565     3009.380665  ...            0.313293
# min          1.000000     -170.603072  ...            0.000000
# 25%        894.000000     3436.365848  ...            1.000000
# 50%       1263.000000     5319.769349  ...            1.000000
# 75%       1944.000000     7680.717827  ...            1.000000
# max       6700.000000    16715.565404  ...            1.000000
#
#        bank_months_count  has_other_cards  proposed_credit_limit  \
# count     1000000.000000   1000000.000000         1000000.000000
# mean           10.839303         0.222988             515.851010
# std            12.116875         0.416251             487.559902
# min            -1.000000         0.000000             190.000000
# 25%            -1.000000         0.000000             200.000000
# 50%             5.000000         0.000000             200.000000
# 75%            25.000000         0.000000             500.000000
# max            32.000000         1.000000            2100.000000
#
#        foreign_request  session_length_in_minutes  keep_alive_session  \
# count   1000000.000000             1000000.000000      1000000.000000
# mean          0.025242                   7.544940            0.576947
# std           0.156859                   8.033106            0.494044
# min           0.000000                  -1.000000            0.000000
# 25%           0.000000                   3.103053            0.000000
# 50%           0.000000                   5.114321            1.000000
# 75%           0.000000                   8.866131            1.000000
# max           1.000000                  85.899143            1.000000
#
#        device_distinct_emails_8w  device_fraud_count           month
# count             1000000.000000           1000000.0  1000000.000000
# mean                    1.018312                 0.0        3.288674
# std                     0.180761                 0.0        2.209994
# min                    -1.000000                 0.0        0.000000
# 25%                     1.000000                 0.0        1.000000
# 50%                     1.000000                 0.0        3.000000
# 75%                     1.000000                 0.0        5.000000
# max                     2.000000                 0.0        7.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# ### Feature Selection
#
# Let's perform feature selection by removing low-variance and non-informative variables, keeping only those relevant for fraud risk analysis.
# #### Identify Strong Signals of Fraud
# ##### Numerical Features

# %%
pd.set_option('display.max_columns', None)
df.groupby("fraud_bool").mean(numeric_only=True)
# Out:
#               income  name_email_similarity  prev_address_months_count  \
# fraud_bool
# 0           0.561313               0.494815                  16.839647
# 1           0.686635               0.393161                   5.861365
#
#             current_address_months_count  customer_age  days_since_request  \
# fraud_bool
# 0                              86.273232     33.609125            1.025383
# 1                             114.801161     40.858645            1.054615
#
#             intended_balcon_amount  zip_count_4w  velocity_6h  velocity_24h  \
# fraud_bool
# 0                         8.713907   1572.138693  5670.664988   4771.528849
# 1                         3.962009   1622.311542  5183.913444   4613.138798
#
#             velocity_4w  bank_branch_count_8w  \
# fraud_bool
# 0           4857.444566            184.923747
# 1           4755.844185            133.976426
#
#             date_of_birth_distinct_emails_4w  credit_risk_score  \
# fraud_bool
# 0                                   9.526521         130.469904
# 1                                   7.443195         177.590353
#
#             email_is_free  phone_home_valid  phone_mobile_valid  \
# fraud_bool
# 0                0.528423          0.418906            0.890112
# 1                0.661075          0.253060            0.850576
#
#             bank_months_count  has_other_cards  proposed_credit_limit  \
# fraud_bool
# 0                   10.843426         0.224533             512.303162
# 1                   10.469580         0.084414             833.986762
#
#             foreign_request  session_length_in_minutes  keep_alive_session  \
# fraud_bool
# 0                  0.024962                   7.537306            0.579571
# 1                  0.050322                   8.229520            0.341645
#
#             device_distinct_emails_8w  device_fraud_count     month
# fraud_bool
# 0                            1.017630                 0.0  3.285582
# 1                            1.079427                 0.0  3.565962

# %% [markdown]
# **Insights:**
# - Fraudulent users tend to have higher income levels
# - Fraud is more common among older customers
# - Fraudsters have short previous address history but long current address (suspicious pattern)
# - Fraud strongly associated with higher credit risk
# - Fraudulent profiles request higher credit limits
# - More mismatch = more fraud
# - Fraudsters use free emails more often
# - Fraudsters have less valid contact info
# - Fraudulent users tend to have lower intended amounts
# - Session length is slightly higher and keep-alive session is lower in fraud, which can mean possibly shorter or inconsistent sessions
# - Fraudulent accounts may behave less consistently or differently over time
# - Fraudsters are less likely to have multiple cards
#
# **Columns that doesn’t differentiate fraud:**
# - days_since_request
# - zip_count_4w
# - velocity_6h
# - velocity_24h
# - velocity_4w
# - bank_months_count
# - device_fraud_count
# - month

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# #### - Payment Type

# %%
pd.crosstab(df["payment_type"], df["fraud_bool"], normalize="index")
# Out:
# fraud_bool           0         1
# payment_type
# AA            0.994718  0.005282
# AB            0.988749  0.011251
# AC            0.983302  0.016698
# AD            0.989178  0.010822
# AE            0.996540  0.003460

# %% [markdown]
# - Certain payment types (especially AC - 1.67%) are significantly more associated with fraud.

# %%
pd.crosstab(df["payment_type"], df["fraud_bool"], normalize="index").plot(kind="bar")

plt.title("Fraud Rate by Payment Type")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# #### - Employment Status

# %%
pd.crosstab(df["employment_status"], df["fraud_bool"], normalize="index")
# Out:
# fraud_bool                0         1
# employment_status
# CA                 0.987814  0.012186
# CB                 0.993109  0.006891
# CC                 0.975316  0.024684
# CD                 0.996230  0.003770
# CE                 0.997664  0.002336
# CF                 0.998070  0.001930
# CG                 0.984547  0.015453

# %% [markdown]
# - Certain employment categories (especially CC - 2.47%) show much higher fraud risk.

# %%
pd.crosstab(df["employment_status"], df["fraud_bool"], normalize="index").plot(kind="bar")

plt.title("Fraud Rate by Employment Status")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# #### - Housing Status

# %%
pd.crosstab(df["housing_status"], df["fraud_bool"], normalize="index")
# Out:
# fraud_bool             0         1
# housing_status
# BA              0.962534  0.037466
# BB              0.993992  0.006008
# BC              0.993852  0.006148
# BD              0.991361  0.008639
# BE              0.996559  0.003441
# BF              0.995806  0.004194
# BG              0.996032  0.003968

# %% [markdown]
# - Housing status BA (3.75%) is a major fraud indicator.

# %%
pd.crosstab(df["housing_status"], df["fraud_bool"], normalize="index").plot(kind="bar")

plt.title("Fraud Rate by House Status")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# #### - Source

# %%
pd.crosstab(df["source"], df["fraud_bool"], normalize="index")
# Out:
# fraud_bool         0         1
# source
# INTERNET    0.989006  0.010994
# TELEAPP     0.984109  0.015891

# %% [markdown]
# - Transactions initiated via TELEAPP show a slightly higher fraud rate compared to INTERNET, indicating potential channel-based risk differences.

# %% [markdown]
# #### - Device OS

# %%
pd.crosstab(df["device_os"], df["fraud_bool"], normalize="index")
# Out:
# fraud_bool         0         1
# device_os
# linux       0.994845  0.005155
# macintosh   0.986029  0.013971
# other       0.994240  0.005760
# windows     0.975306  0.024694
# x11         0.988794  0.011206

# %% [markdown]
# - Users on Windows devices show significantly higher fraud rates compared to other operating systems.

# %%
pd.crosstab(df["device_os"], df["fraud_bool"], normalize="index").plot(kind="bar")

plt.title("Fraud Rate by Device OS")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# #### Foreign Request

# %%
pd.crosstab(df["foreign_request"], df["fraud_bool"], normalize="index")
# Out:
# fraud_bool              0         1
# foreign_request
# 0                0.989255  0.010745
# 1                0.978013  0.021987

# %%
pd.crosstab(df["foreign_request"], df["fraud_bool"], normalize="index").plot(kind="bar")

plt.title("Fraud Rate by Foreign Request")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# ### Detailed analysis on some feautures

# %% [markdown]
# #### - Income

# %%
pd.crosstab(df["income"], df["fraud_bool"], normalize="index")
# Out:
# fraud_bool         0         1
# income
# 0.1         0.994227  0.005773
# 0.2         0.993684  0.006316
# 0.3         0.993351  0.006649
# 0.4         0.992663  0.007337
# 0.5         0.992051  0.007949
# 0.6         0.991221  0.008779
# 0.7         0.991181  0.008819
# 0.8         0.989076  0.010924
# 0.9         0.978362  0.021638

# %% [markdown]
# - Fraud increases with higher income levels, especially at the top range (0.9 - 2.16%).

# %%
import seaborn as sns

fraud_df = df[df["fraud_bool"] == 1]

sns.histplot(fraud_df["income"], bins=50)
plt.title("Income Distribution for Fraud Cases")
plt.xlabel("Income")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### - Credit Risk Score

# %%
df["credit_risk_score"].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     83.0
# 0.50    122.0
# 0.75    178.0
# Name: credit_risk_score, dtype: float64

# %%
pd.crosstab(
    pd.qcut(df["credit_risk_score"], 5, duplicates="drop"),
    df["fraud_bool"],
    normalize="index"
)
# Out:
# fraud_bool                0         1
# credit_risk_score
# (-170.001, 73.0]   0.993882  0.006118
# (73.0, 107.0]      0.993279  0.006721
# (107.0, 141.0]     0.993470  0.006530
# (141.0, 192.0]     0.988637  0.011363
# (192.0, 389.0]     0.975299  0.024701

# %% [markdown]
# - Higher credit risk scores are strongly associated with fraud (2.47%).

# %%
plt.figure()
df.boxplot(column="credit_risk_score", by="fraud_bool")

plt.title("Credit Risk Score by Fraud Status")
plt.xlabel("Fraud (0 = No, 1 = Yes)")
plt.ylabel("Credit Risk Score")

plt.suptitle("")
plt.show()

# %% [markdown]
# The boxplot shows that fraudulent transactions tend to have higher credit risk scores compared to non-fraudulent ones. The median and interquartile range are shifted upward for fraud cases, indicating a clear difference in distribution. However, there is some overlap between the two groups, suggesting that this feature alone is not sufficient for classification but provides strong predictive value when combined with other features.

# %% [markdown]
# #### - Intended Balcon Amount

# %%
df["intended_balcon_amount"].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25   -1.181488
# 0.50   -0.830507
# 0.75    4.984176
# Name: intended_balcon_amount, dtype: float64

# %%
pd.crosstab(
    pd.qcut(df["intended_balcon_amount"], 3, duplicates="drop"),
    df["fraud_bool"],
    normalize="index"
)
# Out:
# fraud_bool                     0         1
# intended_balcon_amount
# (-15.532, -1.063]       0.988066  0.011934
# (-1.063, -0.516]        0.986314  0.013686
# (-0.516, 112.957]       0.992533  0.007467

# %%
import matplotlib.pyplot as plt

plt.figure()
df.boxplot(column="intended_balcon_amount", by="fraud_bool")
plt.title("Intended Balcon Amount by Fraud")
plt.suptitle("")
plt.show()

# %% [markdown]
# The distribution of intended transaction amounts shows that fraudulent transactions tend to have slightly lower values, with a higher concentration near zero and negative ranges. However, there is substantial overlap between fraud and non-fraud cases, and the feature exhibits high variability with many outliers. This indicates that while the feature alone is not strongly discriminative, it captures useful behavioral patterns and contributes to the model when combined with other features.

# %% [markdown]
# #### - Device Distinct Emails

# %%
pd.crosstab(df["device_distinct_emails_8w"], df["fraud_bool"], normalize="index")
# Out:
# fraud_bool                        0         1
# device_distinct_emails_8w
# -1                         0.988858  0.011142
#  0                         0.975925  0.024075
#  1                         0.989836  0.010164
#  2                         0.959094  0.040906

# %%
df["device_email_flag"] = df["device_distinct_emails_8w"].map({
    -1: "unknown",
    0: "no_email",
    1: "normal",
    2: "multiple"
})

# %%
df = df.drop(columns=["device_distinct_emails_8w"])

# %%
email_analysis = pd.crosstab(
    df["device_email_flag"],
    df["fraud_bool"],
    normalize="index"
)

email_analysis.plot(kind="bar")

plt.title("Fraud Rate by Device Email Flag")
plt.xlabel("Device Email Flag")
plt.ylabel("Proportion")

plt.legend(["Non-Fraud", "Fraud"])
plt.show()

# %% [markdown]
# The analysis shows that devices associated with multiple email accounts have a significantly higher fraud rate. In particular, the highest category exhibits a clear increase in fraudulent activity, indicating abnormal behavior. This makes the feature one of the strongest predictors in the model, as it captures suspicious patterns in device usage.

# %% [markdown]
# #### - Date of Birth of Distinct Emails

# %%
pd.crosstab(
    df["date_of_birth_distinct_emails_4w"],
    df["fraud_bool"],
    normalize="index"
)
# Out:
# fraud_bool                               0         1
# date_of_birth_distinct_emails_4w
# 0                                 0.952096  0.047904
# 1                                 0.957988  0.042012
# 2                                 0.967634  0.032366
# 3                                 0.981098  0.018902
# 4                                 0.987594  0.012406
# 5                                 0.988292  0.011708
# 6                                 0.989211  0.010789
# 7                                 0.988449  0.011551
# 8                                 0.987043  0.012957
# 9                                 0.988774  0.011226
# 10                                0.991289  0.008711
# 11                                0.993534  0.006466
# 12                                0.992463  0.007537
# 13                                0.993599  0.006401
# 14                                0.994365  0.005635
# 15                                0.994097  0.005903
# 16                                0.993874  0.006126
# 17                                0.993356  0.006644
# 18                                0.992979  0.007021
# 19                                0.993071  0.006929
# 20                                0.994920  0.005080
# 21                                0.992902  0.007098
# 22                                0.994285  0.005715
# 23                                0.994152  0.005848
# 24                                0.994534  0.005466
# 25                                0.993503  0.006497
# 26                                0.993399  0.006601
# 27                                0.995751  0.004249
# 28                                0.986717  0.013283
# 29                                0.995604  0.004396
# 30                                0.997389  0.002611
# 31                                0.996337  0.003663
# 32                                0.986547  0.013453
# 33                                1.000000  0.000000
# 34                                1.000000  0.000000
# 35                                1.000000  0.000000
# 36                                0.967742  0.032258
# 37                                1.000000  0.000000
# 38                                1.000000  0.000000
# 39                                1.000000  0.000000

# %% [markdown]
# - Customers with fewer email associations per date of birth show significantly higher fraud rates, suggesting the use of newly created or isolated identities in fraudulent activity.

# %% [markdown]
# ##### Drop weak / useless signals
# Features were selected based on their discriminatory power between fraudulent and legitimate cases, using statistical comparison of group means and fraud rates.

# %%
df = df.drop(columns=[
    "device_fraud_count", 
    "month", 
    "zip_count_4w", 
    "bank_months_count", 
    "days_since_request",  
    "velocity_6h", 
    "velocity_24h", 
    "velocity_4w",
    "source"
])

# %% [markdown]
# ### Statistical Tests

# %% [markdown]
# **Categorical Features** - Is fraud dependent on this feature?

# %%
from scipy.stats import chi2_contingency

contingency = pd.crosstab(df["foreign_request"], df["fraud_bool"])
chi2, p, dof, expected = chi2_contingency(contingency)

print(p)
# Out:
# 9.787931729792e-64

# %% [markdown]
# A chi-square test confirmed a significant relationship between foreign transactions and fraud occurrence (p < 0.05).

# %%
contingency = pd.crosstab(df["device_email_flag"], df["fraud_bool"])
chi2, p, dof, expected = chi2_contingency(contingency)

print(p)
# Out:
# 0.0

# %% [markdown]
# The number of emails associated with a device shows a statistically significant relationship with fraud, indicating abnormal device behavior.

# %% [markdown]
# **Numerical Features**

# %%
from scipy.stats import ttest_ind

fraud = df[df["fraud_bool"] == 1]["credit_risk_score"]
non_fraud = df[df["fraud_bool"] == 0]["credit_risk_score"]

t, p = ttest_ind(fraud, non_fraud)
print(p)
# Out:
# 0.0

# %% [markdown]
# A t-test showed a significant difference in credit risk scores between fraudulent and legitimate transactions.

# %%
from scipy.stats import ttest_ind

fraud = df[df["fraud_bool"] == 1]["intended_balcon_amount"]
non_fraud = df[df["fraud_bool"] == 0]["intended_balcon_amount"]

t, p = ttest_ind(fraud, non_fraud)
print(p)
# Out:
# 7.408216720914384e-133

# %% [markdown]
# Transaction amount distributions differ significantly between fraud and non-fraud cases, with lower values associated with higher fraud risk.

# %% [markdown]
# **Conclusion:** All selected features show statistically significant differences between fraud and non-fraud transactions.
# This confirms that the observed differences are unlikely due to random variation.
#
# ----

# %% [markdown]
# ##### CSV files for sql

# %%
from sqlalchemy import create_engine
import getpass

password = getpass.getpass("Please, input your SQL password: ")
# Out:
# Please, input your SQL password:  ········

# %%
database_name = "fraud"
connection_string = 'mysql+pymysql://root:' + password + '@localhost/'+ database_name
engine = create_engine(connection_string)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/fraud)

# %%
engine.connect()

# %%
device_email_flag_df = df[["device_email_flag"]].drop_duplicates().reset_index(drop=True)
device_email_flag_df["device_email_flag_id"] = device_email_flag_df.index + 1

device_email_flag_df.to_sql("device_email_flag", engine, if_exists="append", index=False)
# Out:
# 4

# %%
device_os_df = df[["device_os"]].drop_duplicates().reset_index(drop=True)
device_os_df["device_os_id"] = device_os_df.index + 1

device_os_df.to_sql("device_os", engine, if_exists="append", index=False)
# Out:
# 5

# %%
payment_type_df = df[["payment_type"]].drop_duplicates().reset_index(drop=True)
payment_type_df["payment_type_id"] = payment_type_df.index + 1

payment_type_df.to_sql("payment_type", engine, if_exists="append", index=False)
# Out:
# 5

# %%
housing_status_df = df[["housing_status"]].drop_duplicates().reset_index(drop=True)
housing_status_df["housing_status_id"] = housing_status_df.index + 1

housing_status_df.to_sql("housing_status", engine, if_exists="append", index=False)
# Out:
# 7

# %%
employment_status_df = df[["employment_status"]].drop_duplicates().reset_index(drop=True)
employment_status_df["employment_status_id"] = employment_status_df.index + 1

employment_status_df.to_sql("employment_status", engine, if_exists="append", index=False)
# Out:
# 7

# %%
df = df.merge(device_email_flag_df, on="device_email_flag", how="left")
df.drop("device_email_flag", axis=1, inplace=True)

df = df.merge(device_os_df, on="device_os", how="left")
df.drop("device_os", axis=1, inplace=True)

df = df.merge(payment_type_df, on="payment_type", how="left")
df.drop("payment_type", axis=1, inplace=True)

df = df.merge(housing_status_df, on="housing_status", how="left")
df.drop("housing_status", axis=1, inplace=True)

df = df.merge(employment_status_df, on="employment_status", how="left")
df.drop("employment_status", axis=1, inplace=True)

# %%
df["customer_id"] = df.index + 1
df["identity_id"] = df.index + 1
df["session_id"] = df.index + 1
df["transaction_id"] = df.index + 1

# %%
identity_df = df[[
    "identity_id",
    "customer_id",
    "date_of_birth_distinct_emails_4w",
    "phone_mobile_valid",
    "phone_home_valid",
    "email_is_free",
    "name_email_similarity"
]].drop_duplicates()

session_df = df[[
    "session_id",
    "customer_id",
    "device_email_flag_id",
    "device_os_id",
    "keep_alive_session",
    "session_length_in_minutes"
]].drop_duplicates()

transaction_df = df[[
    "transaction_id",
    "customer_id",
    "session_id",
    "payment_type_id",
    "fraud_bool",
    "intended_balcon_amount",
    "proposed_credit_limit",
    "credit_risk_score",
    "foreign_request",
    "bank_branch_count_8w"
]]

customer_df = df[[
    "customer_id",
    "housing_status_id",
    "employment_status_id",
    "customer_age",
    "income",
    "has_other_cards",
    "prev_address_months_count",
    "current_address_months_count"
]].drop_duplicates()

# %%
customer_df.to_sql("customer", engine, if_exists="append", index=False)
# Out:
# 1000000

# %%
identity_df.to_sql("identity", engine, if_exists="append", index=False)
# Out:
# 1000000

# %%
session_df.to_sql("session", engine, if_exists="append", index=False)
# Out:
# 1000000

# %%
transaction_df.to_sql("transaction", engine, if_exists="append", index=False)
# Out:
# 1000000
